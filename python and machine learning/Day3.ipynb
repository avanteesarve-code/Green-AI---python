# %%
thisset = {"apple", "banana", "cherry"}
thisset.add("orange")
print(thisset)
# Out:
# {'orange', 'cherry', 'banana', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}
thisset.remove("cherry")
print(thisset)
# Out:
# {'banana', 'apple'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set1.add("d")
set2.add(4)
set3 = set1 | set2
print(set3)
# Out:
# {1, 2, 3, 4, 'b', 'a', 'c', 'd'}

# %%
def check_entry(student_name, student_list):
    if student_name in student_list:
        print("Entry Allowed")
    else:
        print("Entry Not Allowed")

registered_students = [
    "aman", "siya", "avantee", "rahul", "sneha"
]

name = input("Enter student name: ")

check_entry(name, registered_students)
# Out:
# Entry Allowed

# %%
stu1={"Avantee", "Rahul", "Sneha"}
stu2={"Aman", "Siya", "Avantee"}
common_frnds = stu1 & stu2
print(common_frnds)
# Out:
# {'Avantee'}

# %%
# make a code to login using username and password and send friend request to a friend
users = {
    "aman": "aman",
    "siya": "siya",
    "avantee": "avantee",
    "rashmin": "rashmin",
    "sneha": "sneha"
}
def login(username, password):
    if username in users and users[username] == password:
        print("Login Successful")
        return True
    else:
        print("Login Failed")
        return False
def send_friend_request(sender, receiver):
    if sender in users and receiver in users:
        print(f"Friend request sent from {sender} to {receiver}")
    else:
        print("Sender or receiver does not exist")
username = input("Enter username: ")
password = input("Enter password: ")
if login(username, password):
    friend_name = input("Enter the name of the friend you want to send a request to: ")
    send_friend_request(username, friend_name)
# Out:
# Login Successful
# Friend request sent from avantee to rashmin

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\avantee sarve\appdata\local\programs\python\python313\lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\avantee sarve\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\avantee sarve\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\avantee sarve\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\avantee sarve\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
df = pd.read_csv("predict_energy_consumption.csv")
df.head()
# Out:
#    temperature   humidity  wind_speed  solar_irradiance  energy_consumption
# 0    24.363503  31.107976    5.234114        705.432695          307.398145
# 1    38.767858  52.514057    4.939576        817.013257          412.444548
# 2    33.299849  72.376750   18.125092        325.421109          392.072418
# 3    29.966462  63.933493    4.990924        662.386690          119.254957
# 4    18.900466  68.393669    5.438995        614.571385          117.162261
